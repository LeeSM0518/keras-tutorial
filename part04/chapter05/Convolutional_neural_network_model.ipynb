# %%
# 0. 사용할 패키지 불러오기
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Conv2D, MaxPooling2D, Flatten

# %%
# 1. 데이터셋 생성하기
width = 28
height = 28

# 훈련셋과 시험셋 불러오기
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, width, height, 1).astype('float32') / 255.0
x_test = x_test.reshape(10000, width, height, 1).astype('float32') / 255.0

# 훈련셋과 검증셋 분리
x_val = x_train[50000:]
y_val = y_train[50000:]
x_train = x_train[:50000]
y_train = y_train[:50000]

# 데이터셋 전처리 : 홀수는 1, 짝수는 0으로 반환
y_train = y_train % 2
y_val = y_val % 2
y_test = y_test % 2

# %%
# 2. 모델 구성하기
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(width, height, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 3. 모델 학습과정 설정하기
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_data=(x_val, y_val))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 9s 185us/step - loss: 0.3142 - accuracy: 0.8764 - val_loss: 0.1711 - val_accuracy: 0.9390
# Epoch 2/30
# 50000/50000 [==============================] - 9s 182us/step - loss: 0.1238 - accuracy: 0.9559 - val_loss: 0.0952 - val_accuracy: 0.9678
# Epoch 3/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.0815 - accuracy: 0.9711 - val_loss: 0.0673 - val_accuracy: 0.9759
# Epoch 4/30
# 50000/50000 [==============================] - 9s 182us/step - loss: 0.0649 - accuracy: 0.9768 - val_loss: 0.0559 - val_accuracy: 0.9812
# Epoch 5/30
# 50000/50000 [==============================] - 9s 180us/step - loss: 0.0557 - accuracy: 0.9805 - val_loss: 0.0528 - val_accuracy: 0.9814
# Epoch 6/30
# 50000/50000 [==============================] - 9s 179us/step - loss: 0.0487 - accuracy: 0.9832 - val_loss: 0.0454 - val_accuracy: 0.9836
# Epoch 7/30
# 50000/50000 [==============================] - 9s 180us/step - loss: 0.0439 - accuracy: 0.9849 - val_loss: 0.0448 - val_accuracy: 0.9842
# Epoch 8/30
# 50000/50000 [==============================] - 9s 180us/step - loss: 0.0408 - accuracy: 0.9860 - val_loss: 0.0424 - val_accuracy: 0.9866
# Epoch 9/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.0381 - accuracy: 0.9870 - val_loss: 0.0499 - val_accuracy: 0.9843
# Epoch 10/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.0352 - accuracy: 0.9879 - val_loss: 0.0397 - val_accuracy: 0.9876
# Epoch 11/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.0326 - accuracy: 0.9891 - val_loss: 0.0352 - val_accuracy: 0.9889
# Epoch 12/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.0303 - accuracy: 0.9894 - val_loss: 0.0383 - val_accuracy: 0.9871
# Epoch 13/30
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.0286 - accuracy: 0.9900 - val_loss: 0.0359 - val_accuracy: 0.9884
# Epoch 14/30
# 50000/50000 [==============================] - 9s 176us/step - loss: 0.0269 - accuracy: 0.9903 - val_loss: 0.0328 - val_accuracy: 0.9895
# Epoch 15/30
# 50000/50000 [==============================] - 9s 178us/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.0391 - val_accuracy: 0.9882
# Epoch 16/30
# 50000/50000 [==============================] - 9s 179us/step - loss: 0.0235 - accuracy: 0.9918 - val_loss: 0.0718 - val_accuracy: 0.9769
# Epoch 17/30
# 50000/50000 [==============================] - 9s 178us/step - loss: 0.0225 - accuracy: 0.9922 - val_loss: 0.0327 - val_accuracy: 0.9894
# Epoch 18/30
# 50000/50000 [==============================] - 9s 179us/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0320 - val_accuracy: 0.9898
# Epoch 19/30
# 50000/50000 [==============================] - 9s 184us/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0407 - val_accuracy: 0.9860
# Epoch 20/30
# 50000/50000 [==============================] - 9s 189us/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 0.0292 - val_accuracy: 0.9907
# Epoch 21/30
# 50000/50000 [==============================] - 9s 183us/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0297 - val_accuracy: 0.9906
# Epoch 22/30
# 50000/50000 [==============================] - 9s 184us/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0302 - val_accuracy: 0.9911
# Epoch 23/30
# 50000/50000 [==============================] - 9s 182us/step - loss: 0.0159 - accuracy: 0.9945 - val_loss: 0.0311 - val_accuracy: 0.9907
# Epoch 24/30
# 50000/50000 [==============================] - 9s 181us/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0298 - val_accuracy: 0.9918
# Epoch 25/30
# 50000/50000 [==============================] - 9s 184us/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.0310 - val_accuracy: 0.9906
# Epoch 26/30
# 50000/50000 [==============================] - 9s 184us/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.0317 - val_accuracy: 0.9906
# Epoch 27/30
# 50000/50000 [==============================] - 9s 179us/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0398 - val_accuracy: 0.9894
# Epoch 28/30
# 50000/50000 [==============================] - 9s 181us/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.0510 - val_accuracy: 0.9825
# Epoch 29/30
# 50000/50000 [==============================] - 9s 180us/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0301 - val_accuracy: 0.9913
# Epoch 30/30
# 50000/50000 [==============================] - 9s 178us/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0303 - val_accuracy: 0.9912

# %%
# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 0.5])

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylim([0.8, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# 6. 모델 평가하기
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)
print('## evaluation loss and metrics ##')
print(loss_and_metrics)
# Out:
# 10000/10000 [==============================] - 1s 80us/step
# ## evaluation loss and metrics ##
# [0.023719010082622116, 0.9926999807357788]

# %%
# 7. 모델 사용하기
yhat_test = model.predict(x_test, batch_size=32)

# %matplotlib inline
import matplotlib.pyplot as plt

plt_row = 5
plt_col = 5

plt.rcParams['figure.figsize'] = (10, 10)

f, axarr = plt.subplots(plt_row, plt_col)

for i in range(plt_row * plt_col):
    sub_plt = axarr[i//plt_row, i%plt_col]
    sub_plt.axis('off')
    sub_plt.imshow(x_test[i].reshape(width, height))

    sub_plt_title = 'R: '

    if y_test[i]:
        sub_plt_title += 'odd '
    else:
        sub_plt_title += 'even '

    sub_plt_title += 'P: '

    if yhat_test[i] >= 0.5:
        sub_plt_title += 'odd '
    else:
        sub_plt_title += 'even '

    sub_plt.set_title(sub_plt_title)

plt.show()
